# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.cluster.hierarchy import dendrogram, linkage

# %%
x=np.array([[1,2],[2,3],[3,4],[8,7],[8,8],[25,80],[9,6],[60,47],[12,63],[55,55],[94,55]])

# %%
linked = linkage(x, method="ward")

# %%
plt.figure(figsize=(10, 7))
dendrogram(linked,
            orientation='top',
            labels=np.arange(1,len(x)+1),distance_sort="descending",show_leaf_counts=True)
plt.title('Dendrogram')
plt.xlabel('sample index')
plt.ylabel('distance')
plt.show()

# %%
#--------------------------------------AgglomerativeClustering----------------------------------------

from sklearn.cluster import AgglomerativeClustering

x=np.array([[1,2],[2,3],[3,4],[8,7],[8,8],[25,80],[9,6],[60,47],[12,63],[55,55],[94,55]])

model = AgglomerativeClustering(3)
model.fit(x)

print("Cluster :",model.labels_)
# Out:
# Cluster : [1 1 1 1 1 2 1 0 2 0 0]

# %%
plt.scatter(x[:,0],x[:,1],c=model.labels_)
plt.show()
