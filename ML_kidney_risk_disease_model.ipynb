# %%
import pandas as pd

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("miadul/kidney-disease-risk-dataset")

print("Path to dataset files:", path)
# Out:
# Downloading from https://www.kaggle.com/api/v1/datasets/download/miadul/kidney-disease-risk-dataset?dataset_version_number=1...
# 100%|██████████| 25.2k/25.2k [00:00<00:00, 24.4MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/miadul/kidney-disease-risk-dataset/versions/1

# %%
df=pd.read_csv(f"{path}/kidney_disease_dataset.csv")

# %%
df.head()
# Out:
#    Age  Creatinine_Level   BUN  Diabetes  Hypertension   GFR  Urine_Output  \
# 0   71              0.30  40.9         0             1  46.8        1622.0
# 1   34              1.79  17.1         0             0  43.8        1428.0
# 2   80              2.67  15.0         0             1  78.2        1015.0
# 3   40              0.97  31.1         0             1  92.8        1276.0
# 4   43              2.05  22.8         1             1  62.2        1154.0
#
#    CKD_Status  Dialysis_Needed
# 0           1                0
# 1           1                0
# 2           1                0
# 3           1                0
# 4           0                0

# %%
df['CKD_Status'].value_counts()
# Out:
# CKD_Status
# 1    1172
# 0    1132
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['Age', 'Creatinine_Level', 'BUN', 'Diabetes', 'Hypertension', 'GFR',
#        'Urine_Output', 'CKD_Status', 'Dialysis_Needed'],
#       dtype='object')

# %%
x=df[['Age', 'Creatinine_Level', 'BUN', 'Diabetes', 'Hypertension', 'GFR',
       'Urine_Output']]

# %%
y=df['CKD_Status']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression

# %%
knn_model=KNeighborsClassifier()
NB_model=GaussianNB()
svm_model=SVC()
lr_model=LogisticRegression()

# %%
knn_model.fit(x_train,y_train)
NB_model.fit(x_train,y_train)
svm_model.fit(x_train,y_train)
lr_model.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
knn_pred=knn_model.predict(x_test)
NB_pred=NB_model.predict(x_test)
svm_pred=svm_model.predict(x_test)
lr_pred=lr_model.predict(x_test)

# %%
from sklearn.metrics import classification_report, accuracy_score

# %%
print(classification_report(y_test,knn_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.85      0.82       234
#            1       0.83      0.78      0.80       227
#
#     accuracy                           0.81       461
#    macro avg       0.82      0.81      0.81       461
# weighted avg       0.81      0.81      0.81       461

# %%
print(classification_report(y_test,NB_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.92      0.93       234
#            1       0.92      0.94      0.93       227
#
#     accuracy                           0.93       461
#    macro avg       0.93      0.93      0.93       461
# weighted avg       0.93      0.93      0.93       461

# %%
print(classification_report(y_test,svm_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.66      0.73       234
#            1       0.70      0.84      0.77       227
#
#     accuracy                           0.75       461
#    macro avg       0.76      0.75      0.75       461
# weighted avg       0.76      0.75      0.75       461

# %%
print(classification_report(y_test,lr_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.82      0.84       234
#            1       0.82      0.85      0.83       227
#
#     accuracy                           0.84       461
#    macro avg       0.84      0.84      0.84       461
# weighted avg       0.84      0.84      0.84       461
